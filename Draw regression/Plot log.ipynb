# %%
import pylab
import numpy as np

x = np.linspace(0.5,1,100) # 100 linearly spaced numbers
y = 1/(1+np.exp(-((x*-1.6843))))# computing the values of sin(x)/x

# compose plot
pylab.plot(x,y) # sin(x)/x

pylab.show() # show the plot

# %%
y = 1/(1+np.exp(-((0.81*-1.6843))))
y
# Out:
# 0.20354508428668519
